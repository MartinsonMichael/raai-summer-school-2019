# %%
from matplotlib import pyplot as plt
import numpy as np
from gym_road_cars import CarRacing
import cv2
import os

import matplotlib.pyplot as plt
from IPython.display import display, clear_output
import matplotlib.animation as animation

# %%
env = CarRacing()

# %%
state_pic, _ = env.reset(2)
# Out:
# angle : -0.7741221679460691
# wheels_positions : [[-42.49276862 -15.62552768]
#  [-42.89943676  14.47172504]
#  [ 42.49276862  15.62552768]
#  [ 42.89943676 -14.47172504]]

# %%
plt.figure(figsize=(16, 12))
plt.imshow(state_pic)
plt.scatter(env._agent_car.get_wheels_positions()[:, 0], env._agent_car.get_wheels_positions()[:, 1])
plt.show()

# %%
env._agent_car._car_image.size
# Out:
# array([122,  43])

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1) 

for _ in range(100):
    info, pic
    for _ in range(20):
        (pic, state), r, done, info = env.step(1)
    
    print(info)
    print(state)
    
    clear_output(wait = True)
#     ax.plot(holder.get_history()[:, 0], holder.get_history()[:, 1])
    ax.imshow(pic)
    display(fig)
    plt.pause(0.5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-a664f6bb810d> in <module>
#      13 #     ax.plot(holder.get_history()[:, 0], holder.get_history()[:, 1])
#      14     ax.imshow(pic)
# ---> 15     display(fig)
#      16     plt.pause(0.5)
#
# /data/anaconda3/envs/CDS_Lab/lib/python3.6/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# /data/anaconda3/envs/CDS_Lab/lib/python3.6/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
# ...

# %%
car_track = 5

# %%
state_pic, state_extra = env.reset(car_track_index=car_track)
# Out:
# points A: [1155.17030132   60.20797225]
# points B: [1154.72   10.21]
# points C: [1155.72   10.21]
# rotation_mat: [[ 9.00597716e-03 -9.99959445e-01  6.17782646e+01]
#  [ 9.99959445e-01  9.00597716e-03 -2.75940921e-01]]
# cropped_mask shape (90, 63, 3)
# cropped_image shape (90, 63, 3)
# cropped back shape (90, 63, 3)

# %%
plt.figure(figsize=(16, 12))
plt.imshow(state_pic)
plt.scatter(env._data_loader._tracks[car_track][:, 0], env._data_loader._tracks[car_track][:, 1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fca07d420de5> in <module>
# ----> 1 plt.figure(figsize=(16, 12))
#       2 plt.imshow(state_pic)
#       3 plt.scatter(env._data_loader._tracks[car_track][:, 0], env._data_loader._tracks[car_track][:, 1])
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
env._data_loader._tracks[car_track]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f5d0943aacd7> in <module>
# ----> 1 env._data_loader._tracks[car_track]
#
# NameError: name 'env' is not defined

# %%
env._agent_car.angle
# Out:
# -89.48398854289546

# %%
env._data_loader._cars[0].size
# Out:
# (39, 103)

# %%
plt.imshow(env._data_loader._cars[0].image)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Softmax

# %%
a = tf.cast(np.array([10, 23, 35, -10]), tf.float32)

print(Softmax()(a / 10))
# Out:
# tf.Tensor([0.05886811 0.21600455 0.7171604  0.00796693], shape=(4,), dtype=float32)
